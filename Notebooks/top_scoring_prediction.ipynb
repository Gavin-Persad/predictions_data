# %%
import pandas as pd

# Set the season to analyse
# Replace 'XXX' with the season_id you want to target, e.g. 'f010783f-7fb5-40d8-9e00-6d8a45fa448e'
target_season_id = 'f010783f-7fb5-40d8-9e00-6d8a45fa448e'

# Load data
profiles = pd.read_csv('../CSV/24.09.2026/profiles_rows.csv')
predictions = pd.read_csv('../CSV/24.09.2026/predictions_rows.csv')
fixtures = pd.read_csv('../CSV/24.09.2026/fixtures_rows.csv')
game_weeks = pd.read_csv('../CSV/24.09.2026/game_weeks_rows.csv')
season_players = pd.read_csv('../CSV/24.09.2026/season_players_rows.csv')

if target_season_id == 'XXX':
    raise ValueError(
        "Set target_season_id to the season_id you want to analyse before running the notebook."
    )

# Restrict to the selected season and only players in that season
active_player_ids = season_players.loc[
    season_players['season_id'] == target_season_id,
    'player_id'
].unique()

target_game_week_ids = game_weeks.loc[
    game_weeks['season_id'] == target_season_id,
    'id'
].unique()

active_fixture_ids = fixtures.loc[
    fixtures['game_week_id'].isin(target_game_week_ids),
    'id'
].unique()

filtered_predictions = predictions[
    predictions['user_id'].isin(active_player_ids)
    & predictions['fixture_id'].isin(active_fixture_ids)
].copy()

# Merge predictions with profiles and fixtures
merged = filtered_predictions.merge(
    profiles,
    left_on='user_id',
    right_on='id',
    how='inner',
    suffixes=('_pred', '_profile')
)

merged = merged.merge(
    fixtures,
    left_on='fixture_id',
    right_on='id',
    how='inner',
    suffixes=('', '_fixture')
)

# Select and rename columns as requested
result = merged[['username', 'home_prediction', 'away_prediction', 'home_team', 'away_team', 'home_score', 'away_score']]
result.columns = ['Player Name', 'Home Prediction', 'Away Prediction', 'Home Team', 'Away Team', 'Home Score', 'Away Score']

# Display the result
print(f"Target season: {target_season_id}")
print(f"Merged DataFrame shape: {result.shape}")
print("\nFirst 10 rows:")
print(result.head(10))
# Out:
# Target season: f010783f-7fb5-40d8-9e00-6d8a45fa448e
# Merged DataFrame shape: (2560, 7)
#
# First 10 rows:
#     Player Name  Home Prediction  Away Prediction          Home Team  \
# 0    Mjd-⚒️⚒️⚒️                1                2             Israel
# 1  Chris Torode                2                1        Bournemouth
# 2        Donna                 0                0           Slovenia
# 3  NickBurchall                0                2         Sunderland
# 4           Ian                3                0    Manchester City
# 5  Chris Guyatt                1                0             Israel
# 6  Des McCarthy                2                1      Coventry City
# 7  Des McCarthy                1                3       Ipswich Town
# 8       Murphty                1                2  Nottingham Forest
# 9   Roger Rouse                3                0    Manchester City
#
#        Away Team  Home Score  Away Score
# 0   Rep. Ireland         NaN         NaN
# 1      Brentford         2.0         2.0
# 2       Scotland         NaN         NaN
# 3        Arsenal         0.0         2.0
# 4     Sunderland         5.0         3.0
# 5   Rep. Ireland         NaN         NaN
# 6      Hull City         0.0         1.0
# 7      Liverpool         0.0         2.0
# 8   Leeds United         0.0         1.0
# 9  Coventry City         1.0         0.0

# %%
# Clean up: remove rows with null/NaN values in scores or predictions
print(f"Before cleanup: {result.shape[0]} rows")

result_clean = result.dropna(subset=['Home Score', 'Away Score', 'Home Prediction', 'Away Prediction']).copy()

# Remove duplicate rows
before_dupes = result_clean.shape[0]
result_clean = result_clean.drop_duplicates()

print(f"After removing NaN: {result_clean.shape[0]} rows")
print(f"Removed {result.shape[0] - result_clean.shape[0]} rows")
print(f"Removed {before_dupes - result_clean.shape[0]} duplicate rows")

# Convert scores from float to integer
result_clean['Home Score'] = result_clean['Home Score'].astype(int)
result_clean['Away Score'] = result_clean['Away Score'].astype(int)

# Display cleaned result
print("\nCleaned data (first 10 rows):")
print(result_clean.head(10))
print(f"\nData types:")
print(result_clean.dtypes)
# Out:
# Before cleanup: 2560 rows
# After removing NaN: 2200 rows
# Removed 360 rows
# Removed 0 duplicate rows
#
# Cleaned data (first 10 rows):
#      Player Name  Home Prediction  Away Prediction          Home Team  \
# 1   Chris Torode                2                1        Bournemouth
# 3   NickBurchall                0                2         Sunderland
# 4            Ian                3                0    Manchester City
# 6   Des McCarthy                2                1      Coventry City
# 7   Des McCarthy                1                3       Ipswich Town
# 8        Murphty                1                2  Nottingham Forest
# 9    Roger Rouse                3                0    Manchester City
# 10  Canada Steve                0                3          Hull City
# 11    Dan Eagles                2                0  Tottenham Hotspur
# 12    Mjd-⚒️⚒️⚒️                1                1      Coventry City
#
#              Away Team  Home Score  Away Score
# 1            Brentford           2           2
# 3              Arsenal           0           2
# 4           Sunderland           5           3
# 6            Hull City           0           1
# 7            Liverpool           0           2
# 8         Leeds United           0           1
# 9        Coventry City           1           0
# 10   Manchester United           2           0
# 11             Everton           0           0
# 12           Hull City           0           1
#
# Data types:
# Player Name        object
# Home Prediction     int64
# Away Prediction     int64
# Home Team          object
# Away Team          object
# Home Score          int64
# Away Score          int64
# dtype: object

# %%
# Keep only exact scoreline predictions (both home and away match)
correct_predictions = result_clean[
    (result_clean['Home Prediction'] == result_clean['Home Score'])
    & (result_clean['Away Prediction'] == result_clean['Away Score'])
].copy()

print(f"Correct predictions count: {correct_predictions.shape[0]}")
print("\nFirst 10 correct predictions:")
print(correct_predictions.head(10))
# Out:
# Correct predictions count: 167
#
# First 10 correct predictions:
#           Player Name  Home Prediction  Away Prediction         Home Team  \
# 3        NickBurchall                0                2        Sunderland
# 20   Alan Taylor-Reed                2                1      Ipswich Town
# 56      Bob sullivan                 2                1      Ipswich Town
# 57        Roger Rouse                2                1   Manchester City
# 59      Bob sullivan                 2                1   Manchester City
# 77                KAV                3                0           Arsenal
# 85       Liam Okeeffe                2                1  Newcastle United
# 98           CFC Stew                1                1            Fulham
# 131  Graham Dongworth                0                2        Sunderland
# 143   Paul and Janine                2                2  Newcastle United
#
#              Away Team  Home Score  Away Score
# 3              Arsenal           0           2
# 20          Sunderland           2           1
# 56          Sunderland           2           1
# 57         Bournemouth           2           1
# 59         Bournemouth           2           1
# 77       Coventry City           3           0
# 85           Hull City           2           1
# 98   Manchester United           1           1
# 131            Arsenal           0           2
# 143    AFC Bournemouth           2           2

# %%
# Sort by highest correct prediction total
sorted_correct = correct_predictions.copy()
sorted_correct['Correct goals predicted'] = (
    sorted_correct['Home Prediction'] + sorted_correct['Away Prediction']
)

sorted_correct = sorted_correct.sort_values(by='Correct goals predicted', ascending=False)

print("Top 10 by Correct goals predicted:")
print(sorted_correct.head(10))
# Out:
# Top 10 by Correct goals predicted:
#         Player Name  Home Prediction  Away Prediction         Home Team  \
# 836    RogerStanton                2                2       Bournemouth
# 505             Ian                2                2  Newcastle United
# 2266       Martin H                2                2       Bournemouth
# 1308         Donna                 2                2       Bournemouth
# 2190   Steve arnold                2                2  Newcastle United
# 461   Bob sullivan                 2                2       Bournemouth
# 467             Mel                2                2       Bournemouth
# 1243            KAV                2                2  Newcastle United
# 1196    Jack Massie                2                2  Newcastle United
# 881    Steve arnold                2                2       Bournemouth
#
#             Away Team  Home Score  Away Score  Correct goals predicted
# 836         Brentford           2           2                        4
# 505   AFC Bournemouth           2           2                        4
# 2266        Brentford           2           2                        4
# 1308        Brentford           2           2                        4
# 2190  AFC Bournemouth           2           2                        4
# 461         Brentford           2           2                        4
# 467         Brentford           2           2                        4
# 1243  AFC Bournemouth           2           2                        4
# 1196        Liverpool           2           2                        4
# 881         Brentford           2           2                        4

# %%
# Show only the top result(s) by Correct goals predicted
max_correct = sorted_correct['Correct goals predicted'].max()

best = sorted_correct[sorted_correct['Correct goals predicted'] == max_correct].copy()

print(f"Top Correct goals predicted: {max_correct}")
print(f"Number of top results: {best.shape[0]}")

# Make the output more presentable
best_display = best[['Player Name', 'Home Team', 'Away Team', 'Home Score', 'Away Score',
                     'Home Prediction', 'Away Prediction', 'Correct goals predicted']]

styled_best = (
    best_display.style.set_table_styles([
        {"selector": "th", "props": [("background-color", "#4472C4"), ("color", "white"), ("border", "1px solid black"), ("font-weight", "bold")]},
        {"selector": "td", "props": [("border", "1px solid black"), ("color", "#1a1a1a"), ("padding", "8px")]},
        {"selector": "tr:nth-child(even) td", "props": [("background-color", "#F2F2F2"), ("color", "#1a1a1a")]},
        {"selector": "tr:nth-child(odd) td", "props": [("background-color", "#FFFFFF"), ("color", "#1a1a1a")]},
    ])
)

display(styled_best)
# Out:
# Top Correct goals predicted: 4
# Number of top results: 35
# <style type="text/css">
# #T_a7701 th {
#   background-color: #4472C4;
#   color: white;
#   border: 1px solid black;
#   font-weight: bold;
# }
# #T_a7701 td {
#   border: 1px solid black;
#   color: #1a1a1a;
#   padding: 8px;
# }
# #T_a7701 tr:nth-child(even) td {
#   background-color: #F2F2F2;
#   color: #1a1a1a;
# }
# #T_a7701 tr:nth-child(odd) td {
#   background-color: #FFFFFF;
#   color: #1a1a1a;
# }
# </style>
# <table id="T_a7701">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7701_level0_col0" class="col_heading level0 col0" >Player Name</th>
#       <th id="T_a7701_level0_col1" class="col_heading level0 col1" >Home Team</th>
#       <th id="T_a7701_level0_col2" class="col_heading level0 col2" >Away Team</th>
#       <th id="T_a7701_level0_col3" class="col_heading level0 col3" >Home Score</th>
#       <th id="T_a7701_level0_col4" class="col_heading level0 col4" >Away Score</th>
#       <th id="T_a7701_level0_col5" class="col_heading level0 col5" >Home Prediction</th>
#       <th id="T_a7701_level0_col6" class="col_heading level0 col6" >Away Prediction</th>
#       <th id="T_a7701_level0_col7" class="col_heading level0 col7" >Correct goals predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7701_level0_row0" class="row_heading level0 row0" >836</th>
#       <td id="T_a7701_row0_col0" class="data row0 col0" >RogerStanton</td>
#       <td id="T_a7701_row0_col1" class="data row0 col1" >Bournemouth</td>
#       <td id="T_a7701_row0_col2" class="data row0 col2" >Brentford</td>
#       <td id="T_a7701_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_a7701_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_a7701_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_a7701_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_a7701_row0_col7" class="data row0 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row1" class="row_heading level0 row1" >505</th>
#       <td id="T_a7701_row1_col0" class="data row1 col0" >Ian</td>
#       <td id="T_a7701_row1_col1" class="data row1 col1" >Newcastle United</td>
#       <td id="T_a7701_row1_col2" class="data row1 col2" >AFC Bournemouth</td>
#       <td id="T_a7701_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_a7701_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_a7701_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_a7701_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_a7701_row1_col7" class="data row1 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row2" class="row_heading level0 row2" >2266</th>
#       <td id="T_a7701_row2_col0" class="data row2 col0" >Martin H</td>
#       <td id="T_a7701_row2_col1" class="data row2 col1" >Bournemouth</td>
#       <td id="T_a7701_row2_col2" class="data row2 col2" >Brentford</td>
#       <td id="T_a7701_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_a7701_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_a7701_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_a7701_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_a7701_row2_col7" class="data row2 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row3" class="row_heading level0 row3" >1308</th>
#       <td id="T_a7701_row3_col0" class="data row3 col0" >Donna </td>
#       <td id="T_a7701_row3_col1" class="data row3 col1" >Bournemouth</td>
#       <td id="T_a7701_row3_col2" class="data row3 col2" >Brentford</td>
#       <td id="T_a7701_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_a7701_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_a7701_row3_col5" class="data row3 col5" >2</td>
#       <td id="T_a7701_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_a7701_row3_col7" class="data row3 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row4" class="row_heading level0 row4" >2190</th>
#       <td id="T_a7701_row4_col0" class="data row4 col0" >Steve arnold</td>
#       <td id="T_a7701_row4_col1" class="data row4 col1" >Newcastle United</td>
#       <td id="T_a7701_row4_col2" class="data row4 col2" >AFC Bournemouth</td>
#       <td id="T_a7701_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_a7701_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_a7701_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_a7701_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_a7701_row4_col7" class="data row4 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row5" class="row_heading level0 row5" >461</th>
#       <td id="T_a7701_row5_col0" class="data row5 col0" >Bob sullivan </td>
#       <td id="T_a7701_row5_col1" class="data row5 col1" >Bournemouth</td>
#       <td id="T_a7701_row5_col2" class="data row5 col2" >Brentford</td>
#       <td id="T_a7701_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_a7701_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_a7701_row5_col5" class="data row5 col5" >2</td>
#       <td id="T_a7701_row5_col6" class="data row5 col6" >2</td>
#       <td id="T_a7701_row5_col7" class="data row5 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row6" class="row_heading level0 row6" >467</th>
#       <td id="T_a7701_row6_col0" class="data row6 col0" >Mel</td>
#       <td id="T_a7701_row6_col1" class="data row6 col1" >Bournemouth</td>
#       <td id="T_a7701_row6_col2" class="data row6 col2" >Brentford</td>
#       <td id="T_a7701_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_a7701_row6_col4" class="data row6 col4" >2</td>
#       <td id="T_a7701_row6_col5" class="data row6 col5" >2</td>
#       <td id="T_a7701_row6_col6" class="data row6 col6" >2</td>
#       <td id="T_a7701_row6_col7" class="data row6 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row7" class="row_heading level0 row7" >1243</th>
#       <td id="T_a7701_row7_col0" class="data row7 col0" >KAV</td>
#       <td id="T_a7701_row7_col1" class="data row7 col1" >Newcastle United</td>
#       <td id="T_a7701_row7_col2" class="data row7 col2" >AFC Bournemouth</td>
#       <td id="T_a7701_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_a7701_row7_col4" class="data row7 col4" >2</td>
#       <td id="T_a7701_row7_col5" class="data row7 col5" >2</td>
#       <td id="T_a7701_row7_col6" class="data row7 col6" >2</td>
#       <td id="T_a7701_row7_col7" class="data row7 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row8" class="row_heading level0 row8" >1196</th>
#       <td id="T_a7701_row8_col0" class="data row8 col0" >Jack Massie</td>
#       <td id="T_a7701_row8_col1" class="data row8 col1" >Newcastle United</td>
#       <td id="T_a7701_row8_col2" class="data row8 col2" >Liverpool</td>
#       <td id="T_a7701_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_a7701_row8_col4" class="data row8 col4" >2</td>
#       <td id="T_a7701_row8_col5" class="data row8 col5" >2</td>
#       <td id="T_a7701_row8_col6" class="data row8 col6" >2</td>
#       <td id="T_a7701_row8_col7" class="data row8 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row9" class="row_heading level0 row9" >881</th>
#       <td id="T_a7701_row9_col0" class="data row9 col0" >Steve arnold</td>
#       <td id="T_a7701_row9_col1" class="data row9 col1" >Bournemouth</td>
#       <td id="T_a7701_row9_col2" class="data row9 col2" >Brentford</td>
#       <td id="T_a7701_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_a7701_row9_col4" class="data row9 col4" >2</td>
#       <td id="T_a7701_row9_col5" class="data row9 col5" >2</td>
#       <td id="T_a7701_row9_col6" class="data row9 col6" >2</td>
#       <td id="T_a7701_row9_col7" class="data row9 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a7701_level0_row10" class="row_heading level0 row10" >764</th>
#       <td id="T_a7701_row10_col0" class="data row10 col0" >Bincho</td>
#       <td id="T_a7701_row10_col1" class="data row10 col1" >Bournemouth</td>
#       <td id="T_a7701_row10_col2" class="data row10 col2" >Brentford</td>
#       <td id="T_a7701_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_a7701_row10_col4" class="data row10 col4"
